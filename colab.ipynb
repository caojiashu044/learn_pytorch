# %%
# !git clone https://github.com/caojiashu044/learn_pytorch.git
# %cd learn_pytorch
# !python read_data.py
# Out:
# Cloning into 'learn_pytorch'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
# /content/learn_pytorch
# python3: can't open file '/content/learn_pytorch/read_data.py': [Errno 2] No such file or directory
