# %%
# !git clone https://github.com/caojiashu044/learn_pytorch.git
# %cd learn_pytorch
# !git pull
# !python read_data.py
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.91 KiB | 1.92 MiB/s, done.
# From https://github.com/caojiashu044/learn_pytorch
#    9008213..3e4fe7d  main       -> origin/main
# Updating 9008213..3e4fe7d
# Fast-forward
#  colab.ipynb  | 87 +++++++++++++++++++++++++++++++++++++++++++++++++++++-------
#  read_data.py |  5 +---
#  2 files changed, 79 insertions(+), 13 deletions(-)
# hello world
